# %% [markdown]
# <a href="https://colab.research.google.com/github/dhruvsus/CSC480StockPrediction/blob/master/Riar_Practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install yfinance
# Out:
# ...
#   Created wheel for yfinance: filename=yfinance-0.1.45-cp36-none-any.whl size=14652 sha256=991919c0266fda969fb92255dd275c72d05ac33bba45d6993379a6d0bc8e47d9
#   Stored in directory: /root/.cache/pip/wheels/0c/d1/df/aa9a7744a4ac353cc9a1f2c3aaea7c1f457fc49de4286f2d88
# Successfully built yfinance
# ...

# %%
# %tensorflow_version 2.x
import tensorflow as tf
import yfinance as yf
import matplotlib.pyplot as plt
import pandas as pd
import csv
# Out:
# TensorFlow 2.x selected.

# %%
df =

# %%
data = yf.download('AAPL', '2018-01-01', '2019-10-04')
data.plot()
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 downloaded
